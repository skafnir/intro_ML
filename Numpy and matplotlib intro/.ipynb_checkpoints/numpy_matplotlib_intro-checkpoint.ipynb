# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

x = np.linspace(1, w10, 100)
y = np.sin(x)
x2 = np.linspace(0, np.pi * 10, 100)
y2 = np.cos(x2)

plt.title('Wykresik')
plt.xlabel('Czas')
plt.ylabel('Przestrzeń')
plt.plot(x, y, x2, y2);
plt.legend(('dane pierwsze', 'dane drugie'))
plt.grid(True)
plt.show()

# %% [markdown]
# Wykresy w jupyter są fajne:
# 1. są łatwe
# 2. są bardzo przydatne
